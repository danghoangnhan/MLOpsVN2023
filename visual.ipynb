# %%
import pandas as pd

# %%
prob_1_data = 'data/captured_data/phase-1/prob-1/'
prob_2_data = 'data/captured_data/phase-1/prob-2/'

# %%
prob_2_data1 = 'data/captured_data/phase-1/prob-2/'
# prob_2_data1 = 'data/trained_data/phase-1/prob-2/'

# %%
prob_2_data = pd.read_parquet(path=prob_1_data)
prob_2_data = prob_2_data.dropna()
prob_2_data
# Out:
#         feature1  feature2 feature3 feature4     feature5 feature6 feature7
# 0           -1.0      -1.0       V4       V6  2789.261637       V0       V1  \
# 1           -1.0      -1.0       V3       V2  1487.622076       V0       V3
# 2           -1.0      -1.0       V4       V3  9287.261034       V0       V4
# 3           -1.0      -1.0       V2       V2  1409.560432       V0       V2
# 4           -1.0      -1.0       V2       V1   858.849618       V0       V2
# ...          ...       ...      ...      ...          ...      ...      ...
# 332355      -1.0      -1.0       V2       V0  2423.243127       V0       V3
# 332356      -1.0      -1.0       V2       V6  7249.801588       V1       V1
# 332357      -1.0      -1.0       V0       V3  3089.124657       V0       V1
# 332358      -1.0      -1.0       V4       V2  5072.883421       V4       V0
# 332359      -1.0      -1.0       V2       V3  1376.357704       V2       V3
#
# ...

# %%
df1 = pd.get_dummies(df1)
df1
# Out:
#         feature1  feature2     feature5  feature8  feature11  feature13
# 0           -1.0      -1.0  2789.261637       4.0        2.0  23.967582  \
# 1           -1.0      -1.0  1487.622076       1.0        2.0  23.523359
# 2           -1.0      -1.0  9287.261034       1.0        2.0  38.988204
# 3           -1.0      -1.0  1409.560432       4.0        3.0  32.898741
# 4           -1.0      -1.0   858.849618       4.0        4.0  31.411723
# ...          ...       ...          ...       ...        ...        ...
# 235215      -1.0      -1.0  4128.090002       2.0        4.0  21.271955
# 235216      -1.0      -1.0  4011.541101       2.0        3.0  20.984528
# 235217      -1.0      -1.0  1238.229603       4.0        3.0  21.735318
# 235218      -1.0      -1.0  1549.651524       4.0        2.0  44.934574
# 235219      -1.0      -1.0  2507.458132       2.0        4.0  25.638292
#
#         feature16  feature18  is_drift  batch_id  ...  feature15_null
# ...
